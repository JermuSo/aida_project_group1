# %%
# load the data using kaggle API
# pip install kaggle
# kaggle API key setup

'''
path = kagglehub.dataset_download("ananaymital/us-used-cars-dataset")

print("Path to dataset files:", path)
'''

import kaggle
import zipfile
import pandas as pd
'''
kaggle.api.dataset_download_files("ananaymital/us-used-cars-dataset", path="us_used_cars", unzip=True)

print("Dataset downloaded to the 'us_used_cars' folder.")

# unzip the file
zip_path = "E:/Koulujutut/AIDA_projekti/aida-projekti-syksy-2024-ryhma-1/docs/us_used_cars/us-used-cars-dataset.zip"

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("us_used_cars")

'''
# Load the dataset - oma filepath tähän
file_path = "E:/Koulujutut/AIDA_projekti/aida-projekti-syksy-2024-ryhma-1/docs/us_used_cars/used_cars_data.csv"  
df = pd.read_csv(file_path)

# Display the first few rows - pikku operaatio :D
display(df.head())
print("Number of rows and columns:", df.shape)

print("Column labels:", df.columns.tolist())
# Out:
# C:\Users\watep\AppData\Local\Temp\ipykernel_17040\1885792038.py:31: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# 2  JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# 3  SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# 4  SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin      city  city_fuel_economy  combine_fuel_economy  ...  transmission  \
# 0   NaN   Bayamon                NaN                   NaN  ...             A
# 1   NaN  San Juan                NaN                   NaN  ...             A
# 2   NaN  Guaynabo               17.0                   NaN  ...             M
# 3   NaN  San Juan                NaN                   NaN  ...             A
# 4   NaN  San Juan                NaN                   NaN  ...             A
#
#           transmission_display  trimId     trim_name  vehicle_damage_category  \
# 0  9-Speed Automatic Overdrive  t83804  Latitude FWD                      NaN
# 1  9-Speed Automatic Overdrive  t86759         S AWD                      NaN
# 2               6-Speed Manual  t58994          Base                      NaN
# 3  8-Speed Automatic Overdrive  t86074    V6 HSE AWD                      NaN
# 4  9-Speed Automatic Overdrive  t86759         S AWD                      NaN
#
#   wheel_system wheel_system_display wheelbase    width  year
# 0          FWD    Front-Wheel Drive  101.2 in  79.6 in  2019
# 1          AWD      All-Wheel Drive  107.9 in  85.6 in  2020
# 2          AWD      All-Wheel Drive  104.3 in  78.9 in  2016
# 3          AWD      All-Wheel Drive    115 in  87.4 in  2020
# 4          AWD      All-Wheel Drive  107.9 in  85.6 in  2020
#
# [5 rows x 66 columns]
# Number of rows and columns: (3000040, 66)
# Column labels: ['vin', 'back_legroom', 'bed', 'bed_height', 'bed_length', 'body_type', 'cabin', 'city', 'city_fuel_economy', 'combine_fuel_economy', 'daysonmarket', 'dealer_zip', 'description', 'engine_cylinders', 'engine_displacement', 'engine_type', 'exterior_color', 'fleet', 'frame_damaged', 'franchise_dealer', 'franchise_make', 'front_legroom', 'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height', 'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab', 'is_certified', 'is_cpo', 'is_new', 'is_oemcpo', 'latitude', 'length', 'listed_date', 'listing_color', 'listing_id', 'longitude', 'main_picture_url', 'major_options', 'make_name', 'maximum_seating', 'mileage', 'model_name', 'owner_count', 'power', 'price', 'salvage', 'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'theft_title', 'torque', 'transmission', 'transmission_display', 'trimId', 'trim_name', 'vehicle_damage_category', 'wheel_system', 'wheel_system_display', 'wheelbase', 'width', 'year']

# %%
# column labels
pd.set_option('display.max_rows', None)
print("Column labels:", df.columns.tolist())
# null count
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# Column labels: ['vin', 'back_legroom', 'bed', 'bed_height', 'bed_length', 'body_type', 'cabin', 'city', 'city_fuel_economy', 'combine_fuel_economy', 'daysonmarket', 'dealer_zip', 'description', 'engine_cylinders', 'engine_displacement', 'engine_type', 'exterior_color', 'fleet', 'frame_damaged', 'franchise_dealer', 'franchise_make', 'front_legroom', 'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height', 'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab', 'is_certified', 'is_cpo', 'is_new', 'is_oemcpo', 'latitude', 'length', 'listed_date', 'listing_color', 'listing_id', 'longitude', 'main_picture_url', 'major_options', 'make_name', 'maximum_seating', 'mileage', 'model_name', 'owner_count', 'power', 'price', 'salvage', 'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'theft_title', 'torque', 'transmission', 'transmission_display', 'trimId', 'trim_name', 'vehicle_damage_category', 'wheel_system', 'wheel_system_display', 'wheelbase', 'width', 'year']
# vin                              0
# back_legroom                159269
# bed                        2980472
# bed_height                 2570942
# bed_length                 2570942
# body_type                    13543
# cabin                      2936507
# city                             0
# city_fuel_economy           491285
# combine_fuel_economy       3000040
# daysonmarket                     0
# dealer_zip                       0
# description                  77901
# engine_cylinders            100581
# engine_displacement         172386
# engine_type                 100581
# exterior_color               49955
# fleet                      1426595
# frame_damaged              1426595
# franchise_dealer                 0
# franchise_make              572635
# front_legroom               159269
# fuel_tank_volume            159269
# fuel_type                    82724
# has_accidents              1426595
# height                      159269
# highway_fuel_economy        491285
# horsepower                  172386
# interior_color              383986
# isCab                      1426595
# is_certified               3000040
# is_cpo                     2817142
# is_new                           0
# is_oemcpo                  2864678
# latitude                         0
# length                      159269
# listed_date                      0
# listing_color                    0
# listing_id                       0
# longitude                        0
# main_picture_url            369093
# major_options               200048
# make_name                        0
# maximum_seating             159269
# mileage                     144387
# model_name                       0
# owner_count                1517013
# power                       481426
# price                            0
# salvage                    1426595
# savings_amount                   0
# seller_rating                40872
# sp_id                           96
# sp_name                          0
# theft_title                1426595
# torque                      517793
# transmission                 64185
# transmission_display         64185
# trimId                      115827
# trim_name                   116294
# vehicle_damage_category    3000040
# wheel_system                146732
# wheel_system_display        146732
# wheelbase                   159269
# width                       159269
# year                             0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)
display(df.head())
print("Number of rows and columns:", df.shape)
print("Column labels:", df.columns.tolist())

print("Data Types and Info:")
print(df.info())

print("Statistical Summary of Numerical Columns:")
df = df.query('year >= 2000')
round(df.select_dtypes(exclude = ['object']).describe() , 2)


cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    unique_values = df[col].unique()
    print(f"Total unique values: {len(unique_values)}")
    print("Top 10 most common values:")
    print(df[col].value_counts().head(10))  # Show top 10 most common values
    print("\n")
# Out:
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# 2  JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# 3  SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# 4  SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin      city  city_fuel_economy  combine_fuel_economy  ...  transmission  \
# 0   NaN   Bayamon                NaN                   NaN  ...             A
# 1   NaN  San Juan                NaN                   NaN  ...             A
# 2   NaN  Guaynabo               17.0                   NaN  ...             M
# 3   NaN  San Juan                NaN                   NaN  ...             A
# 4   NaN  San Juan                NaN                   NaN  ...             A
#
#           transmission_display  trimId     trim_name  vehicle_damage_category  \
# 0  9-Speed Automatic Overdrive  t83804  Latitude FWD                      NaN
# 1  9-Speed Automatic Overdrive  t86759         S AWD                      NaN
# 2               6-Speed Manual  t58994          Base                      NaN
# 3  8-Speed Automatic Overdrive  t86074    V6 HSE AWD                      NaN
# 4  9-Speed Automatic Overdrive  t86759         S AWD                      NaN
#
#   wheel_system wheel_system_display wheelbase    width  year
# 0          FWD    Front-Wheel Drive  101.2 in  79.6 in  2019
# 1          AWD      All-Wheel Drive  107.9 in  85.6 in  2020
# 2          AWD      All-Wheel Drive  104.3 in  78.9 in  2016
# 3          AWD      All-Wheel Drive    115 in  87.4 in  2020
# 4          AWD      All-Wheel Drive  107.9 in  85.6 in  2020
#
# [5 rows x 66 columns]
# Number of rows and columns: (2987792, 66)
# Column labels: ['vin', 'back_legroom', 'bed', 'bed_height', 'bed_length', 'body_type', 'cabin', 'city', 'city_fuel_economy', 'combine_fuel_economy', 'daysonmarket', 'dealer_zip', 'description', 'engine_cylinders', 'engine_displacement', 'engine_type', 'exterior_color', 'fleet', 'frame_damaged', 'franchise_dealer', 'franchise_make', 'front_legroom', 'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height', 'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab', 'is_certified', 'is_cpo', 'is_new', 'is_oemcpo', 'latitude', 'length', 'listed_date', 'listing_color', 'listing_id', 'longitude', 'main_picture_url', 'major_options', 'make_name', 'maximum_seating', 'mileage', 'model_name', 'owner_count', 'power', 'price', 'salvage', 'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'theft_title', 'torque', 'transmission', 'transmission_display', 'trimId', 'trim_name', 'vehicle_damage_category', 'wheel_system', 'wheel_system_display', 'wheelbase', 'width', 'year']
# Data Types and Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2987792 entries, 0 to 3000039
# Data columns (total 66 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   vin                      object
#  1   back_legroom             object
#  2   bed                      object
#  3   bed_height               object
#  4   bed_length               object
#  5   body_type                object
#  6   cabin                    object
#  7   city                     object
#  8   city_fuel_economy        float64
#  9   combine_fuel_economy     float64
#  10  daysonmarket             int64
#  11  dealer_zip               object
#  12  description              object
#  13  engine_cylinders         object
#  14  engine_displacement      float64
#  15  engine_type              object
#  16  exterior_color           object
#  17  fleet                    object
#  18  frame_damaged            object
#  19  franchise_dealer         bool
#  20  franchise_make           object
#  21  front_legroom            object
#  22  fuel_tank_volume         object
#  23  fuel_type                object
#  24  has_accidents            object
#  25  height                   object
#  26  highway_fuel_economy     float64
#  27  horsepower               float64
#  28  interior_color           object
#  29  isCab                    object
#  30  is_certified             float64
#  31  is_cpo                   object
#  32  is_new                   bool
#  33  is_oemcpo                object
#  34  latitude                 float64
#  35  length                   object
#  36  listed_date              object
#  37  listing_color            object
#  38  listing_id               int64
#  39  longitude                float64
#  40  main_picture_url         object
#  41  major_options            object
#  42  make_name                object
#  43  maximum_seating          object
#  44  mileage                  float64
#  45  model_name               object
#  46  owner_count              float64
#  47  power                    object
#  48  price                    float64
#  49  salvage                  object
#  50  savings_amount           int64
#  51  seller_rating            float64
#  52  sp_id                    float64
#  53  sp_name                  object
#  54  theft_title              object
#  55  torque                   object
#  56  transmission             object
#  57  transmission_display     object
#  58  trimId                   object
#  59  trim_name                object
#  60  vehicle_damage_category  float64
#  61  wheel_system             object
#  62  wheel_system_display     object
#  63  wheelbase                object
#  64  width                    object
#  65  year                     int64
# dtypes: bool(2), float64(14), int64(4), object(46)
# memory usage: 1.5+ GB
# None
# Statistical Summary of Numerical Columns:
# Total unique values: 2987752
# Top 10 most common values:
# vin
# 2G1105S30K9136221    2
# 1N4BL4DV0LC262865    2
# 5N1AT2MV6LC789928    2
# 1N4BL4BV8LC255052    2
# 2FMPK4K97LBB07668    2
# 5FNYF6H10MB018426    2
# 5FNYF6H94MB000906    2
# 5XYPG4A31KG501728    2
# 7FART6H88LE013181    2
# 1FMSK8DH8LGC57819    2
# Name: count, dtype: int64
#
#
# Total unique values: 197
# Top 10 most common values:
# back_legroom
# 38.3 in    113852
# 43.6 in    102488
# 37.4 in     87363
# --          81404
# 35.7 in     77135
# 39 in       76074
# 40.4 in     72743
# 38 in       66898
# 38.6 in     63954
# 39.9 in     61498
# Name: count, dtype: int64
#
#
# Total unique values: 4
# Top 10 most common values:
# bed
# Short      11546
# Long        4663
# Regular     2829
# Name: count, dtype: int64
#
#
# Total unique values: 2
# Top 10 most common values:
# bed_height
# --    428592
# Name: count, dtype: int64
#
#
# Total unique values: 83
# Top 10 most common values:
# bed_length
# 67.1 in    83655
# 67.4 in    50872
# 69.9 in    44920
# 78.9 in    38342
# 76.3 in    32738
# 69.3 in    20998
# 61.7 in    12700
# 60.3 in    11807
# 98.3 in    11799
# 79.4 in    10516
# Name: count, dtype: int64
#
#
# Total unique values: 10
# Top 10 most common values:
# body_type
# SUV / Crossover    1414944
# Sedan               739636
# Pickup Truck        472433
# Hatchback            88045
# Minivan              79713
# Coupe                68528
# Van                  46968
# Wagon                40378
# Convertible          24152
# Name: count, dtype: int64
#
#
# Total unique values: 5
# Top 10 most common values:
# cabin
# Crew Cab          51028
# Extended Cab       7618
# Regular Cab        2762
# Large Crew Cab     1524
# Name: count, dtype: int64
#
#
# Total unique values: 4683
# Top 10 most common values:
# city
# Houston         43675
# San Antonio     24902
# Columbus        18285
# Miami           17983
# Jacksonville    16792
# Las Vegas       16325
# Tampa           15295
# Phoenix         14747
# Dallas          14584
# Orlando         14450
# Name: count, dtype: int64
#
#
# Total unique values: 9182
# Top 10 most common values:
# dealer_zip
# 77477    7317
# 33619    5612
# 77034    5250
# 77074    5211
# 91401    5104
# 77090    4933
# 85382    4800
# 85297    4737
# 85260    4655
# 30096    4620
# Name: count, dtype: int64
#
#
# Total unique values: 2508283
# Top 10 most common values:
# description
# [!@@Additional Info@@!]Front Wheel Drive,Power Steering,ABS,4-Wheel Disc Brakes,Brake Assist,Wheel Covers,Steel Wheels,Tires - Front Performance,Tires - Rear Performance,Temporary Spare Tire,Power Mirror(s),Rear Defrost,Intermittent Wipers,Daytime Running Lights,Automatic Headlights,AM/FM Stereo,MP3 Player,Steering Wheel Audio Controls,Bluetooth Connection,Auxiliary Audio Input,Bucket Seats,Rear Bench Seat,Adjustable Steering Wheel,Trip Computer,Power Windows,Keyless Entry,Power Door Locks,Cruise Control,Adaptive Cruise Control,Climate Control,A/C,Cloth Seats,Driver Vanity Mirror,Passenger Vanity Mirror,Floor Mats,Power Windows,Power Door Locks,Trip Computer,Security System,Engine Immobilizer,Traction Control,Stability Control,Traction Control,Front Side Air Bag,Lane Departure Warning,Lane Keeping Assist,Lane Departure Warning,Tire Pressure Monitor,Driver Air Bag,Passenger Air Bag,Front Head Air Bag,Rear Head Air Bag,Passenger Air Bag Sensor,Child Safety Locks,Back-Up Camera                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1064
# -                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     977
# [!@@Additional Info@@!]Bluetooth                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      950
# Please call us for more information.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  718
# **Sale Price includes a Factory Rebate if applicable on this vehicle and is valid on a cash or financed purchase only by an individual for their personal use. The sale price does not apply to a lease. The Factory Rebates may not be available on this vehicle if you elect to take advantage of a Special Alternative APR or Special Lease program. Some Factory Rebates are California Resident specific and may vary for residents of other states. NO sales to Dealers, Brokers or Exporters. For out of state purchase, customers must be present to purchase. If shipping is required, dealership must facilitate; no exceptions. Please contact us for special Multi-Vehicle or Fleet pricing.  Prices are plus government fees and taxes, any finance charges,  documentary fee,  electronic registration fee, any emission testing charge and .75 per new tire state tire fee. *We only provide four gallons of gas at purchase. We make every effort to provide accurate information, but please verify before purchasing. Leasing & financing available on approved credit. Trade-ins accepted. Subject to prior sale. While every reasonable effort is made to ensure the accuracy of this information, we are not responsible for any errors or omissions contained on these pages. Please verify any information in question with Huntington Beach Chrysler Dodge Jeep Ram.[!@@Additional Info@@!]Engine: 3.6L V6 24V VVT,Transmission: 8-Speed Automatic                                                                                                                                            556
# [!@@Additional Info@@!]Turbocharged,Front Wheel Drive,Power Steering,ABS,4-Wheel Disc Brakes,Brake Assist,Aluminum Wheels,Tires - Front Performance,Tires - Rear Performance,Temporary Spare Tire,Power Mirror(s),Rear Defrost,Intermittent Wipers,Variable Speed Intermittent Wipers,Daytime Running Lights,Automatic Headlights,AM/FM Stereo,MP3 Player,Bluetooth Connection,Auxiliary Audio Input,Steering Wheel Audio Controls,Bucket Seats,Rear Bench Seat,Adjustable Steering Wheel,Trip Computer,Power Windows,Keyless Start,Keyless Entry,Power Door Locks,Cruise Control,Adaptive Cruise Control,Climate Control,Multi-Zone A/C,A/C,Cloth Seats,Driver Vanity Mirror,Passenger Vanity Mirror,Driver Illuminated Vanity Mirror,Passenger Illuminated Visor Mirror,Floor Mats,Keyless Start,Power Windows,Power Door Locks,Trip Computer,Security System,Engine Immobilizer,Traction Control,Stability Control,Traction Control,Front Side Air Bag,Lane Departure Warning,Lane Keeping Assist,Lane Departure Warning,Tire Pressure Monitor,Driver Air Bag,Passenger Air Bag,Front Head Air Bag,Rear Head Air Bag,Passenger Air Bag Sensor,Knee Air Bag,Child Safety Locks,Back-Up Camera                                                                                                                                                                                                                                                                                                                                                                                                                       525
# [!@@Additional Info@@!]Turbocharged,Front Wheel Drive,Power Steering,ABS,4-Wheel Disc Brakes,Brake Assist,Aluminum Wheels,Tires - Front Performance,Tires - Rear Performance,Temporary Spare Tire,Power Mirror(s),Rear Defrost,Intermittent Wipers,Variable Speed Intermittent Wipers,Rear Spoiler,Daytime Running Lights,Automatic Headlights,Fog Lamps,AM/FM Stereo,MP3 Player,Bluetooth Connection,Telematics,Auxiliary Audio Input,Smart Device Integration,Requires Subscription,Steering Wheel Audio Controls,Power Driver Seat,Bucket Seats,Driver Adjustable Lumbar,Pass-Through Rear Seat,Rear Bench Seat,Adjustable Steering Wheel,Trip Computer,Power Windows,Leather Steering Wheel,Keyless Start,Keyless Entry,Power Door Locks,Cruise Control,Adaptive Cruise Control,Climate Control,Multi-Zone A/C,A/C,Cloth Seats,Driver Vanity Mirror,Passenger Vanity Mirror,Driver Illuminated Vanity Mirror,Passenger Illuminated Visor Mirror,Floor Mats,Keyless Start,Power Windows,Power Door Locks,Trip Computer,Security System,Engine Immobilizer,Traction Control,Stability Control,Traction Control,Front Side Air Bag,Lane Departure Warning,Lane Keeping Assist,Lane Departure Warning,Tire Pressure Monitor,Driver Air Bag,Passenger Air Bag,Front Head Air Bag,Rear Head Air Bag,Passenger Air Bag Sensor,Knee Air Bag,Child Safety Locks,Back-Up Camera                                                                                                                                                                                                                                             512
# [!@@Additional Info@@!]Turbocharged,All Wheel Drive,Power Steering,ABS,4-Wheel Disc Brakes,Brake Assist,Aluminum Wheels,Tires - Front All-Season,Tires - Rear All-Season,Temporary Spare Tire,Sun/Moonroof,Generic Sun/Moonroof,Heated Mirrors,Power Mirror(s),Integrated Turn Signal Mirrors,Rear Defrost,Privacy Glass,Intermittent Wipers,Variable Speed Intermittent Wipers,Rear Spoiler,Power Door Locks,Daytime Running Lights,Automatic Headlights,Fog Lamps,AM/FM Stereo,Satellite Radio,MP3 Player,Bluetooth Connection,Auxiliary Audio Input,HD Radio,Smart Device Integration,Requires Subscription,Steering Wheel Audio Controls,Power Driver Seat,Bucket Seats,Heated Front Seat(s),Driver Adjustable Lumbar,Pass-Through Rear Seat,Rear Bench Seat,Adjustable Steering Wheel,Trip Computer,Power Windows,Keyless Entry,Power Door Locks,Keyless Entry,Power Door Locks,Keyless Start,Cruise Control,Adaptive Cruise Control,Climate Control,Multi-Zone A/C,A/C,Woodgrain Interior Trim,Cloth Seats,Driver Vanity Mirror,Passenger Vanity Mirror,Driver Illuminated Vanity Mirror,Passenger Illuminated Visor Mirror,Floor Mats,Cargo Shade,Remote Engine Start,Keyless Start,Power Door Locks,Power Windows,Trip Computer,Engine Immobilizer,Security System,Traction Control,Stability Control,Traction Control,Front Side Air Bag,Lane Departure Warning,Lane Keeping Assist,Lane Departure Warning,Blind Spot Monitor,Cross-Traffic Alert,Tire Pressure Monitor,Driver Air Bag,Passenger Air Bag,Front Head Air Bag,Rear Head Air Bag,Passenger Air Bag Sensor,Child Safety Locks,Back-Up Camera     480
# [!@@Additional Info@@!]Front Wheel Drive,Power Steering,ABS,4-Wheel Disc Brakes,Brake Assist,Aluminum Wheels,Tires - Front Performance,Tires - Rear Performance,Temporary Spare Tire,Power Mirror(s),Rear Defrost,Intermittent Wipers,Rear Spoiler,Daytime Running Lights,Automatic Headlights,Fog Lamps,AM/FM Stereo,MP3 Player,Steering Wheel Audio Controls,Bluetooth Connection,Telematics,Auxiliary Audio Input,Smart Device Integration,Requires Subscription,Bucket Seats,Pass-Through Rear Seat,Rear Bench Seat,Adjustable Steering Wheel,Trip Computer,Power Windows,Leather Steering Wheel,Keyless Entry,Power Door Locks,Keyless Start,Keyless Entry,Power Door Locks,Cruise Control,Adaptive Cruise Control,Climate Control,A/C,Cloth Seats,Driver Vanity Mirror,Passenger Vanity Mirror,Floor Mats,Remote Engine Start,Keyless Start,Power Windows,Power Door Locks,Trip Computer,Security System,Engine Immobilizer,Traction Control,Stability Control,Traction Control,Front Side Air Bag,Lane Departure Warning,Lane Keeping Assist,Lane Departure Warning,Tire Pressure Monitor,Driver Air Bag,Passenger Air Bag,Front Head Air Bag,Rear Head Air Bag,Passenger Air Bag Sensor,Child Safety Locks,Back-Up Camera                                                                                                                                                                                                                                                                                                                                                                                     417
# All advertised prices exclude government fees and taxes, any finance charges, any dealer document preparation charge, and any emission testing charge. While we try to make sure that all prices posted here are accurate at all times, we cannot be responsible for typographical and other errors that may appear on the site. We make every effort to provide you the most accurate, up-to-the-minute information; however, it is your responsibility to verify with the Dealer that all details listed are accurate. The dealership is not responsible for typographical, pricing, product information, advertising or shipping errors. Advertised prices and available quantities are subject to change without notice. All rates and offers are dependent on bank approval, which varies based on applicant's credit as well as the vehicle.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    416
# Name: count, dtype: int64
#
#
# Total unique values: 40
# Top 10 most common values:
# engine_cylinders
# I4                      1417010
# V6                       735380
# V8                       276553
# V8 Flex Fuel Vehicle      78372
# I4 Hybrid                 72712
# V6 Flex Fuel Vehicle      68303
# H4                        65829
# I3                        54301
# I6                        27592
# I6 Diesel                 23364
# Name: count, dtype: int64
#
#
# Total unique values: 40
# Top 10 most common values:
# engine_type
# I4                      1417010
# V6                       735380
# V8                       276553
# V8 Flex Fuel Vehicle      78372
# I4 Hybrid                 72712
# V6 Flex Fuel Vehicle      68303
# H4                        65829
# I3                        54301
# I6                        27592
# I6 Diesel                 23364
# Name: count, dtype: int64
#
#
# Total unique values: 27831
# Top 10 most common values:
# exterior_color
# Black                     161282
# White                     125127
# Summit White               96413
# Silver                     78458
# Gray                       77302
# Oxford White               59072
# Blue                       50442
# Bright White Clearcoat     43467
# Red                        41448
# Silver Ice Metallic        37835
# Name: count, dtype: int64
#
#
# Total unique values: 3
# Top 10 most common values:
# fleet
# False    1226754
# True      334450
# Name: count, dtype: int64
#
#
# Total unique values: 3
# Top 10 most common values:
# frame_damaged
# False    1546287
# True       14917
# Name: count, dtype: int64
#
#
# Total unique values: 49
# Top 10 most common values:
# franchise_make
# Ford         395104
# Chevrolet    338296
# Toyota       186635
# Honda        184445
# Jeep         176815
# Nissan       152542
# Hyundai      107052
# Kia           92645
# RAM           77079
# Buick         74349
# Name: count, dtype: int64
#
#
# Total unique values: 93
# Top 10 most common values:
# front_legroom
# 40.9 in    229487
# 43.9 in    150816
# 41.3 in    144455
# 41 in      144079
# 41.2 in    129296
# 42.3 in    126840
# 44.5 in    100347
# 41.5 in     94845
# 42.2 in     89756
# 43 in       89043
# Name: count, dtype: int64
#
#
# Total unique values: 182
# Top 10 most common values:
# fuel_tank_volume
# 26 gal      202746
# 13.2 gal    162846
# 18.5 gal    144685
# 14 gal      138859
# 14.5 gal     99618
# 15.9 gal     92609
# 19.5 gal     76583
# 19 gal       76525
# 24 gal       70973
# 18 gal       64191
# Name: count, dtype: int64
#
#
# Total unique values: 9
# Top 10 most common values:
# fuel_type
# Gasoline                  2590722
# Flex Fuel Vehicle          155959
# Hybrid                      76012
# Diesel                      44146
# Biodiesel                   25855
# Electric                    16416
# Compressed Natural Gas        146
# Propane                         6
# Name: count, dtype: int64
#
#
# Total unique values: 3
# Top 10 most common values:
# has_accidents
# False    1319867
# True      241337
# Name: count, dtype: int64
#
#
# Total unique values: 468
# Top 10 most common values:
# height
# 66.1 in    85144
# 66.3 in    77549
# 56.5 in    73167
# 56.9 in    72447
# 65.4 in    69071
# 69.9 in    65565
# 77.2 in    62001
# 58.1 in    61725
# 57.1 in    57839
# 66.5 in    57100
# Name: count, dtype: int64
#
#
# Total unique values: 45428
# Top 10 most common values:
# interior_color
# Black                869177
# Gray                 193991
# Jet Black            186195
# Black (Ebony)        142835
# Black (Charcoal)     111990
# Medium Earth Gray     44471
# Brown (Beige)         40937
# Brown (Tan)           27356
# jet black             26034
# Charcoal Black        25095
# Name: count, dtype: int64
#
#
# Total unique values: 3
# Top 10 most common values:
# isCab
# False    1274420
# True      286784
# Name: count, dtype: int64
#
#
# Total unique values: 2
# Top 10 most common values:
# is_cpo
# True    182896
# Name: count, dtype: int64
#
#
# Total unique values: 2
# Top 10 most common values:
# is_oemcpo
# True    135362
# Name: count, dtype: int64
#
#
# Total unique values: 794
# Top 10 most common values:
# length
# 231.9 in    97714
# 183.1 in    64724
# 231.7 in    57805
# 182.3 in    54886
# 184.5 in    51201
# 182.1 in    50421
# 189.8 in    45270
# 176.4 in    41251
# 182.7 in    40943
# 191.7 in    37069
# Name: count, dtype: int64
#
#
# Total unique values: 1699
# Top 10 most common values:
# listed_date
# 2020-09-03    77203
# 2020-09-02    71090
# 2020-09-04    71083
# 2020-09-05    68288
# 2020-08-29    60584
# 2020-08-28    59440
# 2020-08-27    58899
# 2020-08-26    56723
# 2020-09-10    55995
# 2020-08-21    52287
# Name: count, dtype: int64
#
#
# Total unique values: 15
# Top 10 most common values:
# listing_color
# WHITE      664514
# BLACK      586422
# UNKNOWN    398475
# SILVER     384064
# GRAY       377054
# RED        250452
# BLUE       248503
# GREEN       23187
# BROWN       22105
# ORANGE      11458
# Name: count, dtype: int64
#
#
# Total unique values: 2404691
# Top 10 most common values:
# main_picture_url
# https://static.cargurus.com/images/forsale/2020/03/11/13/10/2019_ford_f-150-pic-7425370749204324819-152x114.jpeg                  913
# https://static.cargurus.com/images/forsale/2018/08/22/16/29/2019_chevrolet_silverado_1500-pic-1827095471508643688-152x114.jpeg    630
# https://static.cargurus.com/images/forsale/2018/06/22/10/17/2018_mazda_cx-5-pic-2796852983994209380-152x114.jpeg                  589
# https://static.cargurus.com/images/forsale/2020/06/10/18/01/2020_ram_1500-pic-7150704426973780195-152x114.jpeg                    545
# https://static.cargurus.com/images/forsale/2020/01/14/06/10/2020_honda_civic-pic-8659105345295960931-152x114.jpeg                 507
# https://static.cargurus.com/images/forsale/2016/09/06/16/13/2017_jeep_grand_cherokee-pic-2442996225738902688-152x114.jpeg         481
# https://static.cargurus.com/images/forsale/2020/02/03/09/59/2020_ford_f-150-pic-5997287215374485728-152x114.jpeg                  466
# https://static.cargurus.com/images/forsale/2019/11/09/02/31/2020_mazda_cx-5-pic-2938050670830075085-152x114.jpeg                  444
# https://static.cargurus.com/images/forsale/2020/05/07/21/30/2020_nissan_altima-pic-1546255082781942827-152x114.jpeg               415
# https://static.cargurus.com/images/forsale/2018/08/22/16/29/2019_chevrolet_equinox-pic-8636318547577505155-152x114.jpeg           410
# Name: count, dtype: int64
#
#
# Total unique values: 279826
# Top 10 most common values:
# major_options
# ['Alloy Wheels', 'Bluetooth', 'Backup Camera']                               89079
# ['Alloy Wheels']                                                             40222
# ['Steel Wheels']                                                             40039
# ['Bluetooth', 'Backup Camera']                                               36871
# ['Steel Wheels', 'Bluetooth', 'Backup Camera']                               36411
# ['Bluetooth']                                                                33072
# ['Backup Camera']                                                            31118
# ['Alloy Wheels', 'Bluetooth', 'Backup Camera', 'Android Auto', 'CarPlay']    25999
# ['Alloy Wheels', 'Bluetooth']                                                24064
# ['Alloy Wheels', 'Backup Camera']                                            23505
# Name: count, dtype: int64
#
#
# Total unique values: 68
# Top 10 most common values:
# make_name
# Ford         474049
# Chevrolet    373835
# Toyota       238504
# Nissan       217746
# Honda        214188
# Jeep         168048
# Hyundai      136089
# Kia          112328
# RAM          102545
# GMC           98967
# Name: count, dtype: int64
#
#
# Total unique values: 13
# Top 10 most common values:
# maximum_seating
# 5 seats     1873451
# 7 seats      305236
# 6 seats      300779
# 8 seats      200297
# 4 seats       79872
# 2 seats       33730
# 3 seats       29395
# 15 seats       5903
# 9 seats        3609
# 12 seats       1701
# Name: count, dtype: int64
#
#
# Total unique values: 1010
# Top 10 most common values:
# model_name
# F-150             128283
# Silverado 1500     73174
# 1500               69117
# Equinox            63341
# Escape             56905
# Explorer           48909
# Rogue              48470
# Grand Cherokee     45514
# Camry              43465
# CR-V               43368
# Name: count, dtype: int64
#
#
# Total unique values: 1689
# Top 10 most common values:
# power
# 355 hp @ 5,600 RPM    88300
# 395 hp @ 5,750 RPM    76054
# 138 hp @ 4,900 RPM    59191
# 395 hp @ 5,600 RPM    58859
# 170 hp @ 6,000 RPM    50729
# 181 hp @ 6,000 RPM    49688
# 147 hp @ 6,200 RPM    48717
# 280 hp @ 6,000 RPM    39939
# 170 hp @ 5,600 RPM    37561
# 185 hp @ 6,000 RPM    33712
# Name: count, dtype: int64
#
#
# Total unique values: 3
# Top 10 most common values:
# salvage
# False    1550853
# True       10351
# Name: count, dtype: int64
#
#
# Total unique values: 26120
# Top 10 most common values:
# sp_name
# Carvana                                     6993
# Vroom                                       6035
# Planet Ford                                 2262
# Huntington Beach Chrysler Dodge Jeep Ram    1750
# Honda World                                 1681
# Randy Marion Chevrolet Buick Cadillac       1591
# Brandon Ford                                1513
# Avis Car Sales - Denver                     1444
# Varsity Ford                                1408
# Brunswick Auto Mart                         1398
# Name: count, dtype: int64
#
#
# Total unique values: 3
# Top 10 most common values:
# theft_title
# False    1555977
# True        5227
# Name: count, dtype: int64
#
#
# Total unique values: 1665
# Top 10 most common values:
# torque
# 383 lb-ft @ 4,100 RPM    88300
# 400 lb-ft @ 4,500 RPM    67490
# 410 lb-ft @ 3,950 RPM    56502
# 148 lb-ft @ 200 RPM      53983
# 132 lb-ft @ 4,500 RPM    52438
# 175 lb-ft @ 4,400 RPM    48749
# 260 lb-ft @ 4,800 RPM    43760
# 262 lb-ft @ 4,700 RPM    39755
# 260 lb-ft @ 4,400 RPM    36594
# 203 lb-ft @ 2,000 RPM    36258
# Name: count, dtype: int64
#
#
# Total unique values: 5
# Top 10 most common values:
# transmission
# A              2409906
# CVT             458013
# M                45682
# Dual Clutch      11069
# Name: count, dtype: int64
#
#
# Total unique values: 44
# Top 10 most common values:
# transmission_display
# Automatic                             1249986
# Continuously Variable Transmission     454961
# 6-Speed Automatic                      425509
# 8-Speed Automatic                      333314
# 9-Speed Automatic                      146622
# 6-Speed Automatic Overdrive             88050
# 7-Speed Automatic                       44199
# 5-Speed Automatic                       40197
# 4-Speed Automatic                       34479
# 6-Speed Manual                          20871
# Name: count, dtype: int64
#
#
# Total unique values: 37733
# Top 10 most common values:
# trimId
# t87739    24785
# t86414    15165
# t85772    10537
# t87015    10138
# t85749    10071
# t88293     9679
# t85771     8887
# t87721     8658
# t85748     8085
# t92966     8014
# Name: count, dtype: int64
#
#
# Total unique values: 8163
# Top 10 most common values:
# trim_name
# SE FWD               87605
# S FWD                49062
# XLT SuperCrew 4WD    42051
# LT FWD               39328
# LX FWD               37710
# SV FWD               37304
# LE FWD               37104
# SE AWD               34684
# SE                   32781
# LS FWD               31677
# Name: count, dtype: int64
#
#
# Total unique values: 6
# Top 10 most common values:
# wheel_system
# FWD    1259679
# AWD     695440
# 4WD     583020
# RWD     186811
# 4X2     120929
# Name: count, dtype: int64
#
#
# Total unique values: 6
# Top 10 most common values:
# wheel_system_display
# Front-Wheel Drive    1259679
# All-Wheel Drive       695440
# Four-Wheel Drive      583020
# Rear-Wheel Drive      186811
# 4X2                   120929
# Name: count, dtype: int64
#
#
# Total unique values: 451
# Top 10 most common values:
# wheelbase
# 106.3 in    193403
# 112.2 in    128465
# 145 in       90699
# 105.1 in     85927
# 111.2 in     85285
# 107.3 in     71793
# 111.4 in     58286
# 109.3 in     54822
# 100.6 in     54088
# 106.5 in     53182
# Name: count, dtype: int64
#
#
# Total unique values: 272
# Top 10 most common values:
# width
# 72.4 in    131417
# 73 in      107014
# 96.8 in    104143
# 70.9 in     72974
# 83.5 in     72253
# 72.6 in     67006
# 69.9 in     66659
# 80 in       64943
# 72.8 in     57387
# 81.2 in     56204
# Name: count, dtype: int64

# %%
bruh =('''
data sisältää 3,000,040 riviä and 66 kolumnia
Nähdään, että datassa on neljää eri datatyyppiä: dtypes: bool(2), float64(14), int64(4), object(46).
- **Boolean**: `is_new`, `franchise_dealer`
- **Float**: 14 columns
- **Object**: 46 columns, sisältää kategorista dataa, tekstiä, ja myös muunlaista numeerista tietoa.
- **Int**: `daysonmarket`, ``year`, `listing_id` ja `year`

- `back_legroom`, `front_legroom`, `bed_length`, `wheelbase`, `height`, `length` ja `width` kolumnit sisältävät suffixin `"in"` (esim., "80 in"). Nämä voi muuntaa `float`-arvoiksi.
- `fuel_tank_volume` sisältää suffixin `"gal"` (esim., "18 gal") — tämän voi myös muuntaa `float`-arvoksi.
- `maximum_seating` sisältää suffixin `"seats"` (esim., "5 seats"), jonka voi tallentaa `int`-arvona.


- Kolumnit `is_cpo`, `isCab`, `is_oemcpo`, `fleet`, `frame_damaged`, `has_accidents`, `salvage` ja `theft_title` sisältävät `True` ja `False` sekä `NaN`-arvoja (`is_cpo` ja `is_oemcpo` sisältävät vain `True` ja `NaN`). Nämä on silti tallennettu `object`-tyyppeinä ne voi muuttaa `bool`-tyyppiin.
- Kolumnit `listing_color`, `interior_color`, `fuel_type`, `exterior_color`, `body_type`, `cabin`, `city`, `fuel_type`, `transmission`, `transmission_display`, `make_name`, `franchise_make`, `model_name` ja `sp_name` voi konvertoida mallille helpommin analysoitavaksi (encoding).

- `listed_date` on tallennettu `object`-tyyppinä, mutta sen voi muuttaa `datetime`-tyyppiseksi.



- `bed` sisältää paljon `NaN`-arvoja.
- `bed_height` sisältää `NaN`-arvoja ja `--`-placeholdereita, jotka voi korvata `NaN` arvoilla
- `main_picture_url` -kolumnin voi imo pudottaa, ei todennäköisesti tarjoa analyysille arvoa.

- `major_options` on tallennettu `object`-tyyppinä. Tämä voidaan muuntaa listaksi, josta `extractataan` uniikit arvot ja luodaan jokaiselle binäärikolumni, jossa `1` tarkoittaa, että optio on läsnä, ja `0` että optio puuttuu. (periaatteessa encoding)
Alloy Wheels	Bluetooth	Backup Camera	Android Auto	CarPlay	Steel Wheels
1                 0           0               0                 0 
esim jotenkin tuon näköiseksi :D 

- `power` voi jakaa kahteen kolumniin: `Horsepower` ja `RPM`.
- `torque` voi jakaa myös kahteen kolumniin: `torque` ja `torque_rpm`. molemmat voi tallentaa nyt `float`-arvona.

- `engine_cylinders` ja `engine_type` sisältää saman tiedon, voi valita toisen encodaa sen ja poistaa toisen.
- `trim_name` ja `trimId` periaatteessa sisältävät samaa tietoa, joten `trimId`-kolumnin voi pudottaa ja `encodaa` `trim_name`.
- `wheel_system` ja `wheel_system_display` sama asia, joten voi valita jomman kumman (esim., `wheel_system_display`) ja `encodaa` tarvittaessa.

- `description`-kolumnin voi pudottaa, sillä `major_options`-kolumni sisältää suuren osan `description`-kolumnin tiedoista.

- `combine_fuel_economy`

- `milage arvot pitää tarkistaa`
-
''')

print(bruh)
# Out:
# data sisältää 3,000,040 riviä and 66 kolumnia
# Nähdään, että datassa on neljää eri datatyyppiä: dtypes: bool(2), float64(14), int64(4), object(46).
# - **Boolean**: `is_new`, `franchise_dealer`
# - **Float**: 14 columns
# - **Object**: 46 columns, sisältää kategorista dataa, tekstiä, ja myös muunlaista numeerista tietoa.
# - **Int**: `daysonmarket`, ``year`, `listing_id` ja `year`
#
# - `back_legroom`, `front_legroom`, `bed_length`, `wheelbase`, `height`, `length` ja `width` kolumnit sisältävät suffixin `"in"` (esim., "80 in"). Nämä voi muuntaa `float`-arvoiksi.
# - `fuel_tank_volume` sisältää suffixin `"gal"` (esim., "18 gal") — tämän voi myös muuntaa `float`-arvoksi.
# - `maximum_seating` sisältää suffixin `"seats"` (esim., "5 seats"), jonka voi tallentaa `int`-arvona.
#
#
# - Kolumnit `is_cpo`, `isCab`, `is_oemcpo`, `fleet`, `frame_damaged`, `has_accidents`, `salvage` ja `theft_title` sisältävät `True` ja `False` sekä `NaN`-arvoja (`is_cpo` ja `is_oemcpo` sisältävät vain `True` ja `NaN`). Nämä on silti tallennettu `object`-tyyppeinä ne voi muuttaa `bool`-tyyppiin.
# - Kolumnit `listing_color`, `interior_color`, `fuel_type`, `exterior_color`, `body_type`, `cabin`, `city`, `fuel_type`, `transmission`, `transmission_display`, `make_name`, `franchise_make`, `model_name` ja `sp_name` voi konvertoida mallille helpommin analysoitavaksi (encoding).
#
# - `listed_date` on tallennettu `object`-tyyppinä, mutta sen voi muuttaa `datetime`-tyyppiseksi.
#
#
#
# - `bed` sisältää paljon `NaN`-arvoja.
# - `bed_height` sisältää `NaN`-arvoja ja `--`-placeholdereita, jotka voi korvata `NaN` arvoilla
# - `main_picture_url` -kolumnin voi imo pudottaa, ei todennäköisesti tarjoa analyysille arvoa.
#
# - `major_options` on tallennettu `object`-tyyppinä. Tämä voidaan muuntaa listaksi, josta `extractataan` uniikit arvot ja luodaan jokaiselle binäärikolumni, jossa `1` tarkoittaa, että optio on läsnä, ja `0` että optio puuttuu. (periaatteessa encoding)
# Alloy Wheels	Bluetooth	Backup Camera	Android Auto	CarPlay	Steel Wheels
# 1                 0           0               0                 0
# esim jotenkin tuon näköiseksi :D
#
# - `power` voi jakaa kahteen kolumniin: `Horsepower` ja `RPM`.
# - `torque` voi jakaa myös kahteen kolumniin: `torque` ja `torque_rpm`. molemmat voi tallentaa nyt `float`-arvona.
#
# - `engine_cylinders` ja `engine_type` sisältää saman tiedon, voi valita toisen encodaa sen ja poistaa toisen.
# - `trim_name` ja `trimId` periaatteessa sisältävät samaa tietoa, joten `trimId`-kolumnin voi pudottaa ja `encodaa` `trim_name`.
# - `wheel_system` ja `wheel_system_display` sama asia, joten voi valita jomman kumman (esim., `wheel_system_display`) ja `encodaa` tarvittaessa.
#
# - `description`-kolumnin voi pudottaa, sillä `major_options`-kolumni sisältää suuren osan `description`-kolumnin tiedoista.
#
# - `combine_fuel_economy`
#
# - `milage arvot pitää tarkistaa`
# -

# %%
# vaatii vielä visualisaatiota, esimerkiksi bar chartteja tai korrelaatiomatriisin
